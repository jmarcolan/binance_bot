# %%
import create_bot as cb
# Out:
# /home/app/database.py:37: SAWarning: Can't validate argument 'auto_increment'; can't locate any SQLAlchemy dialect named 'auto'
#   kline_id=  Column(Integer(), auto_increment=True, primary_key=True)
# /home/app/database.py:88: SAWarning: Can't validate argument 'auto_increment'; can't locate any SQLAlchemy dialect named 'auto'
#   bot_id      =  Column(Integer(), auto_increment=True, primary_key=True)
# /home/app/database.py:100: SAWarning: Can't validate argument 'auto_increment'; can't locate any SQLAlchemy dialect named 'auto'
#   ts_id =  Column(Integer(), auto_increment=True, primary_key=True)

# %%
cb.keep_live()
# Out:
# {'symbol': 'EURBUSD', 'price': '1.06080000'}
# 1.0608
# the current step (1.06, 1.064)
# [orderid = 1 ,symbol = EURBUSD]
# True
# /home/app/create_bot.py:44: SAWarning: SELECT statement has a cartesian product between FROM element(s) "Bot_tran" and FROM element "Bot_info".  Apply join condition(s) between each element to resolve.
#   k_lines = list(session.scalars(stmt))
# 2
# 2
# 2
# {'symbol': 'EURBUSD', 'price': '1.06090000'}
# 1.0609
# the current step (1.06, 1.064)
# [orderid = 1 ,symbol = EURBUSD]
# True
# 2
# 2
# 2
# {'symbol': 'EURBUSD', 'price': '1.06090000'}
# 1.0609
# the current step (1.06, 1.064)
# [orderid = 1 ,symbol = EURBUSD]
# True
# 2
# 2
# 2
# {'symbol': 'EURBUSD', 'price': '1.06090000'}
# 1.0609
# the current step (1.06, 1.064)
# [orderid = 1 ,symbol = EURBUSD]
# True
# 2
# 2
# 2
# {'symbol': 'EURBUSD', 'price': '1.06100000'}
# 1.061
# the current step (1.06, 1.064)
# [orderid = 1 ,symbol = EURBUSD]
# True
# 2
# 2
# 2
# ...
